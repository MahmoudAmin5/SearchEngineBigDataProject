# %%
import requests
from bs4 import BeautifulSoup
import time
from urllib.parse import urljoin

start_url = "https://www.w3schools.com"
visited = set()  
to_visit = [start_url]  

i = 0

while to_visit:
    url = to_visit.pop(0)
    if url in visited:
        continue

    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.content, "html.parser")

        visited.add(url)
        print(f"Visiting: {url}")

        title_tag = soup.find("title")
        if title_tag:
            title = title_tag.text
        else:
            title = "No Title"

        print(f"{i}: Title: {title}")
        i += 1

        for link in soup.find_all("a", href=True):
            href = link['href']

           
            full_url = urljoin(url, href)

            if full_url.startswith("https://www.w3schools.com") and full_url not in visited:
                to_visit.append(full_url)

        time.sleep(1)

    except Exception as e:
        print(f"Error visiting {url}: {e}")
# Out:
# Visiting: https://www.w3schools.com
# 0: Title: W3Schools Online Web Tutorials
# Visiting: https://www.w3schools.com/academy/index.php
# 1: Title: Teach Coding
# Visiting: https://www.w3schools.com/spaces/index.php
# 2: Title: Create a Free Website | Website Builder | W3Schools.com | W3Schools Spaces
# Visiting: https://www.w3schools.com/plus/index.php
# 3: Title: Become a Plus User at W3schools - Upgrade to Improve Your Learning Experience
# Visiting: https://www.w3schools.com/html/default.asp
# 4: Title: HTML Tutorial
# Visiting: https://www.w3schools.com/tags/default.asp
# 5: Title: HTML Reference
# Visiting: https://www.w3schools.com/css/default.asp
# 6: Title: CSS Tutorial
# Visiting: https://www.w3schools.com/cssref/default.asp
# 7: Title: CSS Reference
# Visiting: https://www.w3schools.com/css/css_rwd_intro.asp
# 8: Title: Responsive Web Design Introduction
# Visiting: https://www.w3schools.com/bootstrap/bootstrap_ver.asp
# 9: Title: Choose a Bootstrap Version (3, 4 or 5)
# ...

# %%
import numpy as np
urls = np.array(list(visited))
urls.size
# Out:
# 2031

# %%
for i  in range(0,2031):
   try:
        response = requests.get(urls[i])
        soup = BeautifulSoup(response.content, "html.parser")
        text = soup.get_text()
        path = f"C:\\Users\\karem\\OneDrive\\Desktop\\pages\\{i+21334}.txt"
        with open(path, "w", encoding="utf-8") as f:
            f.write(urls[i] + "\n")
            f.write(text)
   except Exception as e:
        print(f"Error scraping {urls}: {e}")
